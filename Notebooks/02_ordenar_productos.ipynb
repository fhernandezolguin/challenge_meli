# %% [markdown]
# ### ¿Cuán rápido puedes ordenar estos productos?

# %% [markdown]
# Sección de ofertas es un listado de productos en oferta ordenados por score de ML y reglas de negocio.
#
# El score va de 0 a 1 donde 1 es el mejor valor posible y determina que tan bueno es un item_id.
#
# Reglas de negocio:
# * Domain_id no se puede repetir en 4 posiciones consecutivas.
# * Vertical no se puede repetir en 1 posición consecutiva.
# * De existir el id 641416750, debe estar en la posición 3 siendo esta regla más fuerte que las demás.
# * De existir el id 22351223 debe estar en la posición 6 siendo esta regla más fuerte que las demás.
# * Las posiciones 9, 10 y 11 deben tener sí o sí items de la categoría  "HOME&DECO" siendo esta regla más fuerte que la 1 y 2.
# * Cumpliendo estas condiciones, el ordenamiento debe respetar un orden de mayor score a menor.
#
# Diseñar algoritmo que devuelva el listado final ordenado de items. Debe escalar eficientemente con el número de ítems y contemplar casos en que no se pueda cumplir restricción.

# %%
# Libraries
import time
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
# Parameters
NAME_FILE = "ordenamiento.csv"
FILES_PATH = '../Files/'

# %%
# Open csv file and view it
df = pd.read_csv(FILES_PATH+NAME_FILE)
print("Number of rows: "+str(df.shape[0]))
df.head()
# Out:
# Number of rows: 5000
#      item_id      vertical              category                   domain  \
# 0  512208310           CPG             PETS FOOD  MLC-CATS_AND_DOGS_FOODS
# 1  468513076            CE           ELECTRONICS               MLC-RANGES
# 2  614337410            CE           ELECTRONICS       MLC-SMART_SPEAKERS
# 3  634351318  APP & SPORTS               APPAREL                MLC-PANTS
# 4  528383704           ACC  VEHICULAR MULTIMEDIA                  MLC-GPS
#
#     score
# 0  0.0272
# 1  0.9256
# 2  0.8304
# 3  0.0560
# 4  0.2334

# %% [markdown]
# ### Create auxiliaries function to support this sorting algorithm.

# %%
def sort_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """Main function to create the sortered dataframe.

    Args:
        df (pd.DataFrame): Dataframe with the information about items and their scores.

    Returns:
        shuffled_df (pd.DataFrame): Dataframe sortered with the constraints of the question.
    """
    
    # Start measuring execution time
    start_time = time.time()

    # Sort the DataFrame by score in descending order
    df = df.sort_values('score', ascending=False)

    # Get a subset of the DataFrame where positions 9, 10, and 11 have items from the "HOME&DECOR" category
    homedeco_df = df[df['category'] == 'HOME&DECOR'].iloc[:3]

    # Remove the items from the "HOME&DECO" category from the original DataFrame
    df = df.drop(homedeco_df.index)

    # Shuffle the remaining items while respecting the consecutive domain and vertical rules
    shuffled_df = shuffle_dataframe(df)

    # Check if item_id 641416750 exists and move it to position 3
    if 641416750 in shuffled_df['item_id'].values:
        shuffled_df = move_item_to_position(shuffled_df, 641416750, 3)

    # Check if item_id 22351223 exists and move it to position 6
    if 22351223 in shuffled_df['item_id'].values:
        shuffled_df = move_item_to_position(shuffled_df, 22351223, 6)

    # Insert the items from the "HOME&DECOR" category at positions 9, 10, and 11
    shuffled_df = pd.concat([shuffled_df.iloc[:8], homedeco_df, shuffled_df.iloc[8:]])

    # Reset index
    shuffled_df.reset_index(drop=True, inplace=True)
    
    # End measuring execution time
    end_time = time.time()
    execution_time = end_time - start_time
    print("Execution time:", execution_time, "seconds")

    return shuffled_df

def move_item_to_position(df: pd.DataFrame, item_id: int, position:int) -> pd.DataFrame:
    """If needed this function takes a row with a certain item_id and move it to the position required.

    Args:
        df (pd.DataFrame): Dataframe used in the algorithm.
        item_id (int): item_id that has to be moved.
        position (int): Position where the item_id

    Returns:
        df (pd.DataFrame): Dataframe where the item_id had being moved.
    """
    # Find the index of the item_id
    idx = df[df['item_id'] == item_id].index[0]
    # Save the row
    df_idx = df[df['item_id'] == item_id]
    # Move the row to the desired position
    df = df.drop(idx)
    df = pd.concat([df.iloc[:position-1], df_idx.loc[idx:idx], df.iloc[position-1:]])
    return df


def shuffle_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """Executes the reorder of the dataframe with the rules of domains and verticals.

    Args:
        df (pd.DataFrame): Dataframe where the scores and items are stored.

    Returns:
        shuffled_df (pd.DataFrame): Reordered dataframe.
    """
    # Shuffle the DataFrame while respecting the consecutive domain and vertical rules
    shuffled_df = pd.DataFrame(columns=df.columns)
    domain_count = 0
    vertical_count = 0

    while len(df) > 0:
        # Filter rows based on the domain and vertical rules
        domain_mask = (df['domain'] != shuffled_df.iloc[-1]['domain']) if len(shuffled_df) > 0 else True
        vertical_mask = (df['vertical'] != shuffled_df.iloc[-1]['vertical']) if len(shuffled_df) > 0 else True
        if len(shuffled_df) == 0:
            filtered_df = df.copy()
        else:
            filtered_df = df.loc[domain_mask & vertical_mask]

        # If no rows match the rules, reset the counts and continue
        if len(filtered_df) == 0:
            domain_count = 0
            vertical_count = 0
            continue

        # Select the row with the highest score from the filtered DataFrame
        max_score_row = filtered_df.loc[[filtered_df['score'].idxmax()]]

        # Append the selected row to the shuffled DataFrame and remove it from the original DataFrame
        shuffled_df = shuffled_df.append(max_score_row)
        df = df.drop(max_score_row.index)

        # Update the counts
        if len(shuffled_df) > 1:
            if shuffled_df.iloc[-1]['domain'] != shuffled_df.iloc[-2]['domain']:
                domain_count = 1
            else:
                domain_count += 1

            if shuffled_df.iloc[-1]['vertical'] != shuffled_df.iloc[-2]['vertical']:
                vertical_count = 1
            else:
                vertical_count += 1

    # Return
    return shuffled_df

# %%
# Executes the algorithm
sortered_dataframe = sort_dataframe(df)
print(sortered_dataframe.shape[0])
# Out:
# Execution time: 14.224012851715088 seconds
# 5000

# %%
# Review of the sortered dataframe
sortered_dataframe
# Out:
#         item_id         vertical                      category  \
# 0     590602034               CE                   ELECTRONICS
# 1     523534468  BEAUTY & HEALTH                 PHARMACEUTICS
# 2     641416750               CE                        MOBILE
# 3     609438042               CE                   ELECTRONICS
# 4     541283090  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 5     634352041               CE                        MOBILE
# 6     610865341  HOME & INDUSTRY                      INDUSTRY
# 7     615879515               CE                        MOBILE
# 8     582188629  HOME & INDUSTRY                    HOME&DECOR
# 9     538407191  HOME & INDUSTRY                    HOME&DECOR
# 10    491549031  HOME & INDUSTRY                    HOME&DECOR
# 11    631987792  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 12    631654974               CE                        MOBILE
# 13    514547899  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 14    908510601               CE                        MOBILE
# 15    530533595  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 16    547284733  HOME & INDUSTRY                    STATIONARY
# 17    587879197               CE                   ELECTRONICS
# 18    611844936  BEAUTY & HEALTH                 PHARMACEUTICS
# 19    619600539               CE                     COMPUTERS
# 20    906344908  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
#
HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 397   601045497               CE                   ELECTRONICS
# 398   906957364  HOME & INDUSTRY                      INDUSTRY
# 399   901157222               CE                   ELECTRONICS
# 400   519676021              CPG                      CLEANING
# 401   555234685               CE                   ELECTRONICS
# 402   909974043  HOME & INDUSTRY                    HOME&DECOR
# 403   916460221               CE                     COMPUTERS
# 404   906914301  HOME & INDUSTRY                    HOME&DECOR
# 405   920452178               CE                        MOBILE
# 406   921647708            T & B                TOYS AND GAMES
# 407   474362419               CE                     COMPUTERS
# 408   581599895  HOME & INDUSTRY                    HOME&DECOR
# 409   621831019               CE                     COMPUTERS
# 410   575898192  BEAUTY & HEALTH                 PHARMACEUTICS
# 411   596777519               CE                        MOBILE
# 412   452533290  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 413   620542383               CE                     COMPUTERS
# 414   435020253  BEAUTY & HEALTH                 PHARMACEUTICS
# 415   611219753               CE                     COMPUTERS
# 416   473941454  BEAUTY & HEALTH              BEAUTY EQUIPMENT
# 417   528557069               CE                     COMPUTERS
# 418   912255885  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 419   615323464               CE                   ELECTRONICS
# 420   636523293              ACC                     AUTOPARTS
# 421   639402587               CE                     COMPUTERS
# 422   554694068  HOME & INDUSTRY                    HOME&DECOR
# 423   593441085               CE                     COMPUTERS
# 424   612710783  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 425   634022322               CE                     COMPUTERS
# 426   618608478  HOME & INDUSTRY                      INDUSTRY
# 427   565754157               CE                   ELECTRONICS
# 428   580371517  HOME & INDUSTRY                      INDUSTRY
# 429   917143468               CE                     COMPUTERS
# 430   538076689     APP & SPORTS            APPAREL ACCESORIES
# 431   514834283               CE                   ELECTRONICS
# 432   639391185  HOME & INDUSTRY                      INDUSTRY
# 433   464135034               CE                   ELECTRONICS
# 434   477808178           OTHERS                  PET PRODUCTS
# 435   611213610               CE                   ELECTRONICS
# 436   534100584            T & B                          BABY
# 437   468513076               CE                   ELECTRONICS
# 438   907512588  HOME & INDUSTRY                      INDUSTRY
# 439   916685492               CE                     COMPUTERS
# 440   550555415  BEAUTY & HEALTH                 PHARMACEUTICS
# 441   912903457               CE                     COMPUTERS
# 442   536161400  HOME & INDUSTRY                    STATIONARY
# 443   916706210               CE                     COMPUTERS
# 444   636871496     APP & SPORTS                      FOOTWEAR
# 445   632405329               CE                     COMPUTERS
# 446   638313157     APP & SPORTS                        SPORTS
# 447   522434893               CE                   ELECTRONICS
# 448   447629316              CPG                        DRINKS
# 449   902600424               CE                   ELECTRONICS
# 450   453889331  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 451   925027638               CE                     COMPUTERS
# 452   548790817  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 453   596777427               CE                        MOBILE
# 454   465451598  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 455   545186527               CE                        MOBILE
# 456   529608455  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 457   617504758               CE                   ELECTRONICS
# 458   570736496  HOME & INDUSTRY                    HOME&DECOR
# 459   573676349               CE                   ELECTRONICS
# 460   469424370  HOME & INDUSTRY                    HOME&DECOR
# 461   479170683               CE                   ELECTRONICS
# 462   454796777  HOME & INDUSTRY                    HOME&DECOR
# 463   907695844               CE                     COMPUTERS
# 464   923210394            T & B                         PARTY
# 465   641041387               CE                     COMPUTERS
# 466   456911545  HOME & INDUSTRY                    STATIONARY
# 467   611221903               CE                     COMPUTERS
# 468   489745316  BEAUTY & HEALTH                 PHARMACEUTICS
# 469   595310698               CE                     COMPUTERS
# 470   549775559  HOME & INDUSTRY                      INDUSTRY
# 471   926843232               CE                   ELECTRONICS
# 472   601165426  BEAUTY & HEALTH              BEAUTY EQUIPMENT
#
HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 695   904648593               CE                        MOBILE
# 696   623620676  HOME & INDUSTRY                    HOME&DECOR
# 697   632634699               CE                     COMPUTERS
# 698   621100365  HOME & INDUSTRY                    HOME&DECOR
# 699   565229144               CE                   ELECTRONICS
# 700   610284019  HOME & INDUSTRY                    HOME&DECOR
# 701   635692020               CE                        MOBILE
# 702   534535820           OTHERS                  PET PRODUCTS
# 703   498970825               CE                   ELECTRONICS
# 704   593453116  HOME & INDUSTRY                      INDUSTRY
# 705   636449023               CE                     COMPUTERS
# 706   566520121     APP & SPORTS                        SPORTS
# 707   639383589               CE                        MOBILE
# 708   532023297  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 709   606750829               CE                   ELECTRONICS
# 710   524907764     APP & SPORTS                        SPORTS
# 711   911145200               CE                        MOBILE
# 712   562066380  HOME & INDUSTRY                      SECURITY
# 713   641909846               CE                        MOBILE
# 714   915037763            T & B                TOYS AND GAMES
# 715   537695244               CE                     COMPUTERS
# 716   507579449     APP & SPORTS                       APPAREL
# 717   597387625               CE                   ELECTRONICS
# 718   617982605  HOME & INDUSTRY                    HOME&DECOR
# 719   584826146               CE                   ELECTRONICS
# 720   550873465  HOME & INDUSTRY                    HOME&DECOR
# 721   597730123               CE                        MOBILE
# 722   524116784  HOME & INDUSTRY        TOOLS AND CONSTRUCTION
# 723   542858744               CE                   ELECTRONICS
# 724   921641109     APP & SPORTS                        SPORTS
# 725   906599885               CE                        MOBILE
# ...
# 4758                                       MLC-SNEAKERS  0.0482
# 4759                                       MLC-SPEAKERS  0.0480
# 4760                                  MLC-OFFICE_CHAIRS  0.0478
# 4761                                  MLC-GYM_DUMBBELLS  0.0476
# 4762                          MLC-ELECTRIC_SCREWDRIVERS  0.0474
# 4763                                 MLC-AIR_MATTRESSES  0.0470
# 4764                     MLC-CLOTHES_HANGING_ORGANIZERS  0.0472
# 4765                    MLC-PORTABLE_CELLPHONE_CHARGERS  0.0466
# 4766                                     MLC-MITER_SAWS  0.0468
# 4767                                         MLC-DRONES  0.0464
# 4768                              MLC-BATHROOM_VANITIES  0.0462
# 4769                                        MLC-CAMERAS  0.0460
# 4770                       MLC-INDUSTRIAL_COOKING_OVENS  0.0458
# 4771                              MLC-BODYWEIGHT_SCALES  0.0456
# 4772                                    MLC-SUPPLEMENTS  0.0454
# 4773                                 MLC-SMART_SPEAKERS  0.0452
# 4774                                           MLC-BEDS  0.0450
# 4775                             MLC-SKIN_CARE_SUPPLIES  0.0448
# 4776                          MLC-IRRIGATION_SPRINKLERS  0.0446
# 4777                                    MLC-SUPPLEMENTS  0.0444
# 4778                          MLC-ELECTRIC_SCREWDRIVERS  0.0442
# 4779                     MLC-VEHICLE_MULTIMEDIA_SYSTEMS  0.0440
# 4780                                    MLC-FRAME_POOLS  0.0438
# 4781                                     MLC-CELLPHONES  0.0432
# 4782                                     MLC-TOOL_BOXES  0.0436
# 4783            MLC-BICYCLE_ACCESSORIES_AND_SPARE_PARTS  0.0428
# 4784                               MLC-WATER_DISPENSERS  0.0434
# 4785                               MLC-ELECTRONIC_DRUMS  0.0426
# 4786                              MLC-CENTRIFUGAL_PUMPS  0.0430
# 4787                                         MLC-WADERS  0.0424
# 4788                         MLC-MINI_COMPONENT_SYSTEMS  0.0422
# 4789                                  MLC-BABY_SUPPLIES  0.0420
# 4790                                    MLC-POOL_LIGHTS  0.0418
# 4791                                    MLC-TV_ANTENNAS  0.0416
# 4792                                MLC-CHRISTMAS_TREES  0.0416
# 4793                                  MLC-HAIR_CLIPPERS  0.0412
# 4794                                     MLC-UNDERPANTS  0.0410
# 4795                                      MLC-NOTEBOOKS  0.0408
# 4796                                       MLC-DOG_BEDS  0.0406
# 4797                                        MLC-LOCKERS  0.0404
# 4798                             MLC-SPORTS_AND_FITNESS  0.0402
# 4799                                     MLC-CELLPHONES  0.0400
# 4800              MLC-BEAUTY_AND_PERSONAL_CARE_SUPPLIES  0.0398
# 4801                                     MLC-CELLPHONES  0.0396
# 4802                             MLC-MAKEUP_TRAIN_CASES  0.0394
# 4803                                     MLC-CELLPHONES  0.0392
# 4804                                  MLC-DINING_CHAIRS  0.0390
# 4805                                        MLC-TABLETS  0.0388
# 4806                                     MLC-MITER_SAWS  0.0386
# 4807                                     MLC-HEADPHONES  0.0382
# 4808                           MLC-TABLE_AND_DESK_LAMPS  0.0384
# 4809                                     MLC-SEAT_BELTS  0.0378
# 4810                                  MLC-OFFICE_CHAIRS  0.0380
# 4811                                  MLC-GYM_DUMBBELLS  0.0376
# 4812                      MLC-ELECTRIC_PRESSURE_WASHERS  0.0374
# 4813            MLC-BICYCLE_ACCESSORIES_AND_SPARE_PARTS  0.0372
# 4814                                  MLC-GAME_CONSOLES  0.0368
# 4815                                     MLC-TREADMILLS  0.0370
# 4816                  MLC-COMPUTER_MONITOR_RISER_STANDS  0.0366
# 4817                        MLC-BLOOD_PRESSURE_MONITORS  0.0364
# 4818  MLC-GAME_CONSOLES_VIDEO_GAMES_AND_ARCADE_MACHINES  0.0362
# 4819                                 MLC-FOOTBALL_BALLS  0.0358
# 4820                                      MLC-NOTEBOOKS  0.0360
# 4821                        MLC-BODY_SKIN_CARE_PRODUCTS  0.0354
# 4822                           MLC-HARD_DRIVES_AND_SSDS  0.0356
# 4823                                       MLC-SNEAKERS  0.0352
# 4824                       MLC-FLEA_AND_TICK_TREATMENTS  0.0350
# 4825        MLC-ELECTRIC_CHARCOAL_AND_FIREWOOD_LIGHTERS  0.0348
# 4826                                 MLC-BICYCLE_PEDALS  0.0344
# 4827                        MLC-ELECTRIC_PAINT_SPRAYERS  0.0346
# 4828                                       MLC-PRINTERS  0.0340
# 4829                         MLC-HOME_LIGHTING_SUPPLIES  0.0342
# 4830                        MLC-AEROBIC_CRUNCH_MACHINES  0.0338
# 4831                          MLC-COMPUTER_MOTHERBOARDS  0.0336
# 4832                              MLC-BATHROOM_VANITIES  0.0334
# 4833                   MLC-ROUTERS_AND_WIRELESS_SYSTEMS  0.0332
# 4834                         MLC-COMBUSTION_WATER_PUMPS  0.0332
# 4835                         MLC-ELECTRIC_WAFFLE_MAKERS  0.0328
# 4836                                    MLC-NAIL_POLISH  0.0326
# 4837                      MLC-COMMERCIAL_NO_LIGHT_SIGNS  0.0324
# 4838                                 MLC-KIDS_TRICYCLES  0.0322
# 4839                    MLC-ELECTRIC_DEMOLITION_HAMMERS  0.0320
# 4840                                       MLC-SPEAKERS  0.0316
# 4841                              MLC-CENTRIFUGAL_PUMPS  0.0318
# 4842                                       MLC-BICYCLES  0.0310
# 4843                              MLC-ELECTRICAL_CABLES  0.0314
# 4844                        MLC-STREAMING_MEDIA_DEVICES  0.0308
# 4845                               MLC-KITCHEN_SUPPLIES  0.0312
# 4846                                    MLC-SUPPLEMENTS  0.0306
# 4847                                     MLC-TABLE_SAWS  0.0304
# 4848                                     MLC-CELLPHONES  0.0302
# 4849                                          MLC-TENTS  0.0300
# 4850                                          MLC-CRIBS  0.0298
# 4851                                    MLC-SUPPLEMENTS  0.0296
# 4852                      MLC-FACIAL_SKIN_CARE_PRODUCTS  0.0294
# 4853                           MLC-SURVEILLANCE_CAMERAS  0.0292
# 4854                      MLC-FACIAL_SKIN_CARE_PRODUCTS  0.0288
# 4855                                     MLC-HOME_DECOR  0.0290
# 4856                             MLC-SKIN_CARE_SUPPLIES  0.0286
# 4857                            MLC-UNIVERSAL_HOME_GYMS  0.0284
# 4858                                 MLC-PLUNGE_ROUTERS  0.0282
# 4859                     MLC-VEHICLE_MULTIMEDIA_SYSTEMS  0.0280
# 4860                                     MLC-CELLPHONES  0.0278
# 4861                                          MLC-SOCKS  0.0276
# 4862                         MLC-GAMEPADS_AND_JOYSTICKS  0.0274
# 4863                            MLC-CATS_AND_DOGS_FOODS  0.0272
# 4864                                   MLC-PC_KEYBOARDS  0.0270
# 4865                             MLC-BATHROOM_GRAB_BARS  0.0266
# 4866               MLC-PORTABLE_EVAPORATIVE_AIR_COOLERS  0.0268
# 4867                               MLC-WELDING_MACHINES  0.0262
# 4868                              MLC-COMPUTER_MONITORS  0.0264
# 4869                               MLC-CHRISTMAS_LIGHTS  0.0256
# 4870                                       MLC-SPEAKERS  0.0260
# 4871                                    MLC-RESPIRATORS  0.0254
# 4872                                     MLC-CELLPHONES  0.0258
# 4873            MLC-INDUSTRIAL_AND_COMMERCIAL_EQUIPMENT  0.0252
# 4874                        MLC-STREAMING_MEDIA_DEVICES  0.0250
# 4875                   MLC-BOX_SPRING_AND_MATTRESS_SETS  0.0248
# 4876                                    MLC-3D_PRINTERS  0.0246
# 4877                                   MLC-STETHOSCOPES  0.0244
# 4878                                     MLC-HEADPHONES  0.0242
# 4879                                        MLC-BEDDING  0.0238
# 4880                                  MLC-VIDEO_CAMERAS  0.0240
# 4881                           MLC-PUSH_AND_RIDING_TOYS  0.0236
# 4882                                MLC-SANDER_MACHINES  0.0234
# 4883                                     MLC-MICROWAVES  0.0228
# 4884                                MLC-TOOL_ORGANIZERS  0.0232
# 4885                                MLC-CAR_LIGHT_BULBS  0.0218
# 4886                                MLC-AIR_COMPRESSORS  0.0230
# 4887                                 MLC-GRAPHICS_CARDS  0.0216
# 4888                                     MLC-MITER_SAWS  0.0226
# 4889                                       MLC-SNEAKERS  0.0214
# 4890                     MLC-INDOOR_CURTAINS_AND_BLINDS  0.0224
# 4891                                     MLC-ALL_IN_ONE  0.0210
# 4892                                  MLC-OFFICE_CHAIRS  0.0222
# 4893                                MLC-SHOOTING_STICKS  0.0208
# 4894                                  MLC-OFFICE_CHAIRS  0.0220
# 4895                  MLC-SURGICAL_AND_INDUSTRIAL_MASKS  0.0204
# 4896                   MLC-BOX_SPRING_AND_MATTRESS_SETS  0.0212
# 4897                                    MLC-MICROPHONES  0.0202
# 4898                                   MLC-FLOOD_LIGHTS  0.0206
# 4899                                       MLC-PRINTERS  0.0200
# 4900                                     MLC-GAS_GRILLS  0.0198
# 4901                                       MLC-SNEAKERS  0.0194
# 4902                               MLC-TV_STORAGE_UNITS  0.0196
# 4903                           MLC-PUSH_AND_RIDING_TOYS  0.0188
# 4904                                MLC-SAFETY_FOOTWEAR  0.0192
# 4905                                    MLC-3D_PRINTERS  0.0186
# 4906                                           MLC-BEDS  0.0190
# 4907                          MLC-AUTOMOBILE_FUEL_PUMPS  0.0184
# 4908                            MLC-CATS_AND_DOGS_FOODS  0.0182
# 4909   MLC-COMBUSTION_BRUSH_CUTTERS_AND_STRING_TRIMMERS  0.0180
# 4910                                   MLC-AIRSOFT_GUNS  0.0178
# 4911                                   MLC-SMARTWATCHES  0.0176
# 4912                    MLC-PORTABLE_ELECTRIC_MASSAGERS  0.0174
# 4913                                 MLC-AIR_MATTRESSES  0.0172
# 4914                        MLC-WALL_AND_CEILING_LIGHTS  0.0170
# 4915                                 MLC-AIR_MATTRESSES  0.0166
# 4916                                 MLC-SEWING_THREADS  0.0168
# 4917                            MLC-AUTOMOTIVE_SPEAKERS  0.0164
# 4918                                       MLC-PERFUMES  0.0162
# 4919                      MLC-COMMERCIAL_AND_EVENT_BAGS  0.0160
# 4920                                    MLC-VIDEO_GAMES  0.0158
# 4921                                       MLC-T_SHIRTS  0.0156
# 4922                                MLC-ELECTRIC_GRILLS  0.0154
# 4923                                       MLC-COSTUMES  0.0150
# 4924                                      MLC-NOTEBOOKS  0.0152
# 4925                               MLC-CAT_LITTER_BOXES  0.0148
# 4926                          MLC-AUTOMOBILE_FUEL_PUMPS  0.0146
# 4927                            MLC-PERMANENT_EPILATORS  0.0144
# 4928                                 MLC-PLUNGE_ROUTERS  0.0142
# 4929                          MLC-UNCLASSIFIED_PRODUCTS  0.0140
# 4930                                   MLC-KITCHEN_POTS  0.0138
# 4931                               MLC-AUDIO_INTERFACES  0.0138
# 4932                         MLC-HOME_LIGHTING_SUPPLIES  0.0134
# 4933            MLC-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS  0.0132
# 4934                                  MLC-PILATES_BALLS  0.0126
# 4935                                     MLC-MICROWAVES  0.0130
# 4936                         MLC-PUNCHING_BAGS_SUPPORTS  0.0122
# 4937                                        MLC-TABLETS  0.0128
# 4938                        MLC-WALL_AND_CEILING_LIGHTS  0.0120
# 4939                                      MLC-NOTEBOOKS  0.0124
# 4940             MLC-ELECTRIC_STAPLERS_AND_BRAD_NAILERS  0.0118
# 4941                                     MLC-HEADPHONES  0.0114
# 4942                                     MLC-HOME_DECOR  0.0116
# 4943                                 MLC-FIRST_AID_KITS  0.0112
# 4944                                   MLC-BICYCLE_BAGS  0.0110
# 4945                              MLC-INTERCOOLER_HOSES  0.0108
# 4946                          MLC-TV_AND_MONITOR_MOUNTS  0.0106
# 4947                             MLC-SKIN_CARE_SUPPLIES  0.0102
# 4948                                     MLC-CELLPHONES  0.0104
# 4949                                         MLC-MAKEUP  0.0100
# 4950                                       MLC-COSTUMES  0.0098
# 4951                                       MLC-SNEAKERS  0.0096
# 4952                                   MLC-SMARTWATCHES  0.0094
# 4953                                   MLC-THERMOMETERS  0.0090
# 4954                              MLC-COMPUTER_MONITORS  0.0092
# 4955                                MLC-BAKERY_MOULDERS  0.0088
# 4956                              MLC-MOTORCYCLE_COVERS  0.0084
# 4957                              MLC-BATHROOM_VANITIES  0.0086
# 4958                                      MLC-E_READERS  0.0082
# 4959                                   MLC-STUFFED_TOYS  0.0078
# 4960                                     MLC-HEADPHONES  0.0080
# 4961                                 MLC-PLUNGE_ROUTERS  0.0074
# 4962                                     MLC-CELLPHONES  0.0076
# 4963                                   MLC-FOG_MACHINES  0.0072
# 4964                         MLC-HOME_LIGHTING_SUPPLIES  0.0070
# 4965                             MLC-LAPTOP_LCD_SCREENS  0.0068
# 4966                                       MLC-COSTUMES  0.0066
# 4967                                        MLC-PANTIES  0.0064
# 4968                                       MLC-PRINTERS  0.0062
# 4969                                MLC-COFFEE_CAPSULES  0.0054
# 4970                                     MLC-CELLPHONES  0.0060
# 4971                                       MLC-HOT_TUBS  0.0052
# 4972                                MLC-VACUUM_CLEANERS  0.0058
# 4973                     MLC-INDOOR_CURTAINS_AND_BLINDS  0.0050
# 4974                                     MLC-CELLPHONES  0.0056
# 4975                                   MLC-GARDEN_HOSES  0.0048
# 4976                   MLC-ROUTERS_AND_WIRELESS_SYSTEMS  0.0046
# 4977                                  MLC-KITCHEN_SINKS  0.0044
# 4978                                     MLC-HEADPHONES  0.0040
# 4979              MLC-DOOR_AND_WINDOW_AWNINGS_AND_EAVES  0.0042
# 4980                                   MLC-TENNIS_BALLS  0.0038
# 4981                 MLC-ULTRASONIC_CAVITATION_MACHINES  0.0034
# 4982                                     MLC-JUMP_ROPES  0.0036
# 4983                              MLC-COMPUTER_MONITORS  0.0030
# 4984                                       MLC-HANDBAGS  0.0032
# 4985                  MLC-SURGICAL_AND_INDUSTRIAL_MASKS  0.0028
# 4986                 MLC-DIGITAL_PORTABLE_MEDIA_PLAYERS  0.0026
# 4987                  MLC-CAMPING_AND_FISHING_EQUIPMENT  0.0024
# 4988                                     MLC-BED_SHEETS  0.0022
# 4989                             MLC-LAUNDRY_DETERGENTS  0.0018
# 4990                                  MLC-HAMMER_DRILLS  0.0020
# 4991                        MLC-AEROBIC_CRUNCH_MACHINES  0.0010
# 4992                            MLC-ELECTRIC_LUNCHBOXES  0.0016
# 4993                                  MLC-EDIBLE_PAPERS  0.0006
# 4994                                   MLC-FLOOD_LIGHTS  0.0014
# 4995                                          MLC-PANTS  0.0004
# 4996                               MLC-ELECTRIC_BLOWERS  0.0012
# 4997                                 MLC-WET_BABY_WIPES  0.0002
# 4998                      MLC-ELECTRIC_PRESSURE_WASHERS  0.0008
# 4999                  MLC-SURGICAL_AND_INDUSTRIAL_MASKS  0.0000
